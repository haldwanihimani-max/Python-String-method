# %%
string = "python"

# %% [markdown]
# # 1. string.capitalize()

# %%
string = "python"
print(string.capitalize())
# Out:
# Python

# %% [markdown]
# # 2. string.casefold()

# %%
string = "Stra@e"
print(string.casefold())
# Out:
# stra@e

# %% [markdown]
# # 3. string.center()

# %%
str1 = "this is python"
print(str1.center(50))
print(str1.center(20,"*"))
# Out:
#                   this is python
# ***this is python***

# %% [markdown]
# # 4. string.count()

# %%
str1 = "this is python"
str1.count("i")
# Out:
# 2

# %% [markdown]
# # 5. string.encode()

# %%
a = str1.encode()
print(a)
# Out:
# b'this is python'

# %%
a = str1.encode()
print(a)
# Out:
# b'this is python'

# %% [markdown]
# # 6. string.endswith()

# %%
str1 = "this is python"

# %%
print(str1.endswith('n'))
# Out:
# True

# %% [markdown]
# # 7. string.expandtabs()

# %%
str1 = "this\tis python"

# %%
print(str1.expandtabs(20))
# Out:
# this                is python

# %% [markdown]
# # 8. string.find()

# %%
str1 = "this is python"

# %%
print(str1.find('is'))
# Out:
# 2

# %% [markdown]
# # 9. string.format()

# %%
age = 10
str1 = "this is python, and i am {}"

# %%
print(str1.format(age))
# Out:
# this is python, and i am 10

# %% [markdown]
# # 10. string.format_map()

# %%
s = "Hi, I'm {n1}. Are you {n2}?"
s = s.format_map({"n1": "Riya", "n2": "Reena"})
print(s)
# Out:
# Hi, I'm Riya. Are you Reena?

# %% [markdown]
# # 11. string.index()

# %%
str1 = "this is python"
print(str1.index("y"))
# Out:
# 9

# %% [markdown]
# # 12. string.isalnum()

# %%
a = "Helloworld"

# %%
print(a.isalnum())
# Out:
# True

# %%
b = "Hello world"

# %%
print(b.isalnum())
# Out:
# False

# %% [markdown]
# # 13 string.isalpha()

# %%
str1 = "this is python"
print(str1.isalpha())
# Out:
# False

# %%
c = "b"

# %%
print(c.isalpha())
# Out:
# True

# %% [markdown]
# # 14 string.isascii()

# %%
str1 = "this is python"
str1 = "`~* helloo"

# %%
print(str1.isascii())
print(str1.isascii())
# Out:
# True
# True

# %% [markdown]
# # 15. string.isdecimal()

# %%
text = "178"

# %%
print(text.isdecimal())
# Out:
# True

# %%
str1 = "this1.23"

# %%
print(str1.isdecimal())
# Out:
# False

# %% [markdown]
# # 16. string.isdigit()

# %%
text = "178"

# %%
print(text.isdigit())
# Out:
# True

# %% [markdown]
# # 17. string.isidentifier()

# %%
str1 = "hello1_is_hello1"

# %%
print(str1.isidentifier())
# Out:
# True

# %% [markdown]
# # 18. string.islower()

# %%
str1 = "hello1_is_hello1"

# %%
print(str1.islower())
# Out:
# True

# %% [markdown]
# # 19. string.isnumeric()

# %%
string = "a1234"

# %%
print(string.isnumeric())
# Out:
# False

# %% [markdown]
# # 20. string.isprintable()

# %%
string = "abc123 57&$"

# %%
print(string.isprintable())
# Out:
# True

# %% [markdown]
# # 21. string.isspace()

# %%
string = " abc123 57&$"

# %%
print(string.isspace())
# Out:
# False

# %% [markdown]
# # 22. string.istitle()

# %%
str1 = "this is python"

# %%
print(str1.istitle())
# Out:
# False

# %%
str2 = "This Is Python"

# %%
print(str2.istitle())
# Out:
# True

# %% [markdown]
# # 23. string.isupper()

# %%
text = "HELLO WORLD"

# %%
print(text.isupper())
# Out:
# True

# %% [markdown]
# # 24. string.join()

# %%
a = "hello"
b = "world"

# %%
c = a.join(b)
print(c)
# Out:
# whelloohellorhellolhellod

# %% [markdown]
# # 25. string.ljust()

# %%
a = "hello"
b = "world"

# %%
print(a.ljust(20,"*"))
# Out:
# hello***************

# %% [markdown]
# # 26. string.lower()

# %%
str1 = "HEloO"

# %%
print(str1.lower())
# Out:
# heloo

# %% [markdown]
# # 27. string.lstrip()

# %%
str1 = "m,.hello world"

# %%
print(str1.lstrip("m,."))
# Out:
# hello world

# %% [markdown]
# # 28. string.maketrans()

# %%
txt="hello ram"
x="ram"
y="son"
mytable=txt.maketrans(x,y)
print(mytable)
# Out:
# {114: 115, 97: 111, 109: 110}

# %%
print(txt.translate(mytable))
# Out:
# hello son

# %% [markdown]
# # 29. string.partition()

# %%
str2 = "This Is Python"

# %%
print(str2.partition("This"))
# Out:
# ('', 'This', ' Is Python')

# %% [markdown]
# # 30. string.removeprefix()

# %%
str2 = "this is python"

# %%
print(str2.removeprefix("this"))
# Out:
#  is python

# %% [markdown]
# # 31. string.removesuffix()

# %%
str2 = "this is python"

# %%
print(str2.removesuffix("python"))
# Out:
# this is

# %% [markdown]
# # 32. string.replace()

# %%
str2 = "this is python"

# %%
print(str2.replace("python", "java"))
# Out:
# this is java

# %% [markdown]
# # 33. string.rfind()

# %%
str2 = "this is python"

# %%
print(str2.rfind("python")) 
print(str2.rfind("java"))
# Out:
# 8
# -1

# %% [markdown]
# # 34. string.rindex()

# %%
str2 = "this is python"

# %%
print(str2.rindex("python"))
# Out:
# 8

# %% [markdown]
# # 35. string.rjust()

# %%
str2 = "this is python"

# %%
print(str2.rjust(30,"*"))
# Out:
# ****************this is python

# %% [markdown]
# # 36. string.rpartition()

# %%
str2 = "this is python"

# %%
print(str2.rpartition("pyt"))
# Out:
# ('this is ', 'pyt', 'hon')

# %% [markdown]
# # 37. string.rsplit()

# %%
str2 = "this is python"

# %%
print(str2.rsplit(" ",1))
# Out:
# ['this is', 'python']

# %% [markdown]
# # 38. string.rstrip()

# %%
str2 = "this is python!!!"

# %%
print(str2.rstrip("!"))
print(str2.rstrip("python"))
# Out:
# this is python
# this is python!!!

# %% [markdown]
# # 39. string.split()

# %%
str2 = "this is is is python"

# %%
print(str2.split("is",2))
# Out:
# ['th', ' ', ' is is python']

# %% [markdown]
# # 40. string.splitlines()

# %%
str2 = "this\npython"

# %%
result = str2.splitlines()

# %%
print(result)
# Out:
# ['this', 'python']

# %% [markdown]
# # 41. string.startswith()

# %%
str2 = "this is python"

# %%
print(str2.startswith("this"))
# Out:
# True

# %% [markdown]
# # 42. string.strip()

# %%
str2 = ",,,this is python,,,"

# %%
print(str2.strip(","))
# Out:
# this is python

# %% [markdown]
# # 43. string.swapcase()

# %%
str2 = "this is python"

# %%
print(str2.swapcase())
# Out:
# THIS IS PYTHON

# %% [markdown]
# # 44. string.title()

# %%
str2 = "this is python"

# %%
print(str2.title())
# Out:
# This Is Python

# %% [markdown]
# # 45. string.translate()

# %%
table = str.maketrans("abc", "123")

# %%
string = "apple, banana, cherry"

# %%
print(string.translate(table))
# Out:
# 1pple, 21n1n1, 3herry

# %%
table = str.maketrans("h", "j", "elo")

# %%
text = "hello world"

# %%
print(text.translate(table))
# Out:
# j wrd

# %% [markdown]
# # 46. string.upper()

# %%
str2 = "this is python"

# %%
print(str2.upper())
# Out:
# THIS IS PYTHON

# %% [markdown]
# # 47. string.zfill()

# %%
string = "42"

# %%
print(string.zfill(5))
# Out:
# 00042

# %%
string = "-42"

# %%
print(string.zfill(8))
# Out:
# -0000042
