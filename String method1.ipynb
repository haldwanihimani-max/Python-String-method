# %%
string = "python"

# %% [markdown]
# # 1. string.capitalize()

# %%
string = "python"
string.capitalize()
# Out:
# 'Python'

# %% [markdown]
# # 2. string.casefold()

# %%
string.casefold()
# Out:
# 'python'

# %% [markdown]
# # 3. string.center()

# %%
str1 = "this is python"
str1.center(50)
# Out:
# '                  this is python                  '

# %% [markdown]
# # 4. string.count()

# %%
str1.count("i")
# Out:
# 2

# %% [markdown]
# # 5. string.encode()

# %%
a = str1.encode()
print(a)
# Out:
# b'this is python'

# %%
a = str1.encode()
print(a)
# Out:
# b'this is python'

# %% [markdown]
# # 6. string.endswith()

# %%
str1 = "this is python"

# %%
str1.endswith('n')
# Out:
# True

# %% [markdown]
# # 7. string.expandtabs()

# %%
str1 = "this\tis python"

# %%
a = str1.expandtabs(20)
print(a)
# Out:
# this                is python

# %% [markdown]
# # 8. string.find()

# %%
str1 = "this is python"

# %%
print(str1.find('is'))
# Out:
# 2

# %% [markdown]
# # 9. string.format()

# %%
age = 10
str1 = "this is python, and i am {}"

# %%
print(str1.format(age))
# Out:
# this is python, and i am 10

# %% [markdown]
# # 10. string.format_map()

# %%
s = "Hi, I'm {n1}. Are you {n2}?"
s = s.format_map({"n1": "Riya", "n2": "Reena"})
print(s)
# Out:
# Hi, I'm Riya. Are you Reena?

# %% [markdown]
# # 11. string.index()

# %%
str1 = "this is python"
str1.index("y")
# Out:
# 9

# %% [markdown]
# # 12. string.isalnum()

# %%
a = "Helloworld"

# %%
print(a.isalnum())
# Out:
# True

# %%
b = "Hello world"

# %%
print(b.isalnum())
# Out:
# False

# %% [markdown]
# # 13 string.isalpha()

# %%
str1 = "this is python"
print(str1.isalpha())
# Out:
# False

# %%
c = "b"

# %%
print(c.isalpha())
# Out:
# True

# %% [markdown]
# # 14 string.isascii()

# %%
str1 = "this is python"

# %%
print(str1.isascii())
# Out:
# True

# %% [markdown]
# # 15. string.isdecimal()

# %%
text = "178"

# %%
print(text.isdecimal())
# Out:
# True

# %%
str1 = "this123"

# %%
print(str1.isdecimal())
# Out:
# False

# %% [markdown]
# # 16. string.isdigit()

# %%
text = "178"

# %%
print(text.isdigit())
# Out:
# True

# %% [markdown]
# # 17. string.isidentifier()

# %%
str1 = "hello1_is_hello1"

# %%
print(str1.isidentifier())
# Out:
# True

# %% [markdown]
# # 18. string.islower()

# %%
str1 = "hello1_is_hello1"

# %%
print(str1.islower())
# Out:
# True

# %% [markdown]
# # 19. string.isnumeric()

# %%
string = "a1234"

# %%
print(string.isnumeric())
# Out:
# False

# %% [markdown]
# # 20. string.isprintable()

# %%
string = "abc123 57&$"

# %%
print(string.isprintable())
# Out:
# True

# %% [markdown]
# # 21. string.isspace()

# %%
string = " abc123 57&$"

# %%
print(string.isspace())
# Out:
# False

# %% [markdown]
# # 22. string.istitle()

# %%
str1 = "this is python"

# %%
print(str1.istitle())
# Out:
# False

# %%
str2 = "This Is Python"

# %%
print(str2.istitle())
# Out:
# True

# %% [markdown]
# # 23. string.isupper()

# %%
text = "HELLO WORLD"

# %%
print(text.isupper())
# Out:
# True

# %% [markdown]
# # 24. string.join()

# %%
a = "hello"
b = "world"

# %%
c = a.join(b)
print(c)
# Out:
# whelloohellorhellolhellod

# %% [markdown]
# # 25. string.ljust()

# %%
a = "hello"
b = "world"

# %%
a.ljust(10,'*')
# Out:
# 'hello*****'

# %% [markdown]
# # 26. string.lower()

# %%
str1 = "HEloO"

# %%
print(str1.lower())
# Out:
# heloo

# %% [markdown]
# # 27. string.lstrip()

# %% [markdown]
# str1 = 'm6.,hello world'

# %%
str1 = "m,.hello world"

# %%
print(str1.lstrip("m,."))
# Out:
# hello world

# %% [markdown]
# # 28. string.maketrans()

# %%
txt="hello ram"
x="ram"
y="son"
mytable=txt.maketrans(x,y)
print(mytable)
# Out:
# {114: 115, 97: 111, 109: 110}

# %%
print(txt.translate(mytable))
# Out:
# hello son

# %% [markdown]
# # 29. string.partition()

# %%
str2 = "This Is Python"

# %%
print(str2.partition("This"))
# Out:
# ('', 'This', ' Is Python')

# %% [markdown]
# # 30. string.removeprefix()

# %%
str2 = "this is python"

# %%
print(str2.removeprefix("this"))
# Out:
#  is python

# %% [markdown]
# # 31. string.removesuffix()

# %%
str2 = "this is python"

# %%
print(str2.removesuffix("python"))
# Out:
# this is
